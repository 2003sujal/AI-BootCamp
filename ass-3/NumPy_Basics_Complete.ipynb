# %% [markdown]
# # NumPy Basics Notebook
#
# ## What is NumPy?
# NumPy (Numerical Python) is a Python library for numerical computing.
#
# - Fast array operations
# - Mathematical functions
# - Matrix operations
# - Used in Data Science and Machine Learning

# %%
import numpy as np

# %%
arr=np.array([10,20,30,40])
arr

# %%
arr2=np.array([[1,2,3],[4,5,6]])
arr2

# %%
arr.ndim

# %%
arr2.shape

# %%
arr2.size

# %%
arr.dtype

# %%
np.zeros((2,3))

# %%
np.ones((2,3))

# %%
np.arange(1,11)

# %%
np.linspace(0,10,5)

# %%
a=np.arange(1,13)
a.reshape(3,4)

# %%
arr[2]

# %%
arr[1:4]

# %%
x=np.array([1,2,3])
y=np.array([4,5,6])
x+y

# %%
x-y

# %%
x*y

# %%
y/x

# %%
np.sqrt(np.array([4,9,16]))

# %%
arr.max()

# %%
arr.min()

# %%
arr.mean()

# %%
arr.sum()

# %%
c=np.array([5,2,9,1])
np.sort(c)

# %%
np.unique(np.array([1,2,2,3,3,4]))

# %%
arr2.T

# %% [markdown]
# ## Cheat Sheet
#
# - np.array()
# - np.zeros()
# - np.ones()
# - np.arange()
# - np.linspace()
# - reshape()
# - shape
# - size
# - ndim
# - dtype
# - max()
# - min()
# - mean()
# - sum()
# - np.sort()
# - np.unique()
# - .T
